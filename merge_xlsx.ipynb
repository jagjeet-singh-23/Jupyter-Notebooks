# %% [markdown]
# <a href="https://colab.research.google.com/github/jagjeet-singh-23/Jupyter-Notebooks/blob/master/merge_xlsx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
# path = "C://Users//Admin//Documents//IMMOLS"
# xlsx = []

# for file in os.listdir(path):
#     if file.endswith('.xlsx'):
#         xlsx.append(file)

# %%
# df1 = pd.read_excel(xlsx[0], '401R')
# df1.dropna(inplace=True)
# df1.head()

# %%
# df2 = pd.read_excel(xlsx[1], 'JOB CARD REPORT')
# df2.dropna(inplace=True)
# df2

# %%
# df3 = pd.read_excel(xlsx[2], '401RR')
# df3.dropna(inplace=True)
# df3.head()

# %%
# df4 = pd.read_excel(xlsx[3], 'e-MMS State')
# df4.dropna(inplace=True)
# df4.head()

# %%
xlsx = pd.ExcelFile('/content/401R_fake_data.xlsx')

# %%
xlsx.sheet_names
# Out:
# ['401R',
#  'JOB CARD REPORT',
#  '401RR',
#  'eMMS State',
#  'TASK PROGRESS REPORT',
#  'Auto Generated Report']

# %%
df1 = pd.read_excel(xlsx, '401R')
# df1.dropna(inplace=True)
# df1.head()

# %%
df2 = pd.read_excel(xlsx, 'JOB CARD REPORT')
# df2.dropna(inplace=True)
# df2.head()
# Out:
#                        Job Card No  Job No   Job Date Task Type Vocab  \
# 0  24-25/XXXXX/JOBCARD/MAIN/123456     NaN 2024-03-05    Repair  AAAA
# 1  24-25/XXXXX/JOBCARD/MAIN/123457     NaN 2024-04-05    Repair  AAAB
# 2  24-25/XXXXX/JOBCARD/MAIN/123458     NaN 2024-05-05    Repair  AAAC
# 3  24-25/XXXXX/JOBCARD/MAIN/123459     NaN 2024-06-05    Repair  AAAD
# 4  24-25/XXXXX/JOBCARD/MAIN/123460     NaN 2024-07-05    Repair  AAAE
#
#   Part No.  Item Code Description  State                 Status        PCD  \
# 0   AB1234     123456  ITEM NAME1    NaN           Modification 2024-05-24
# 1   AB1235     123457  ITEM NAME2    NaN           Modification 2024-06-24
# 2   AB1236     123458  ITEM NAME3    NaN  Modification complete 2024-07-24
# 3   AB1237     123459  ITEM NAME4    NaN           Modification 2024-08-24
# 4   AB1238     123460  ITEM NAME5    NaN  Modification complete 2024-09-24
#
#                     Source Doc. No. Batch/SL No Workshop Job End Date Category
# 0  24-25/XXXXX/INIV/F(Q)401R/123456      ABC123     YYYY   2024-07-09        A
# 1  24-25/XXXXX/INIV/F(Q)401R/123457      ABC124     YYYX   2024-07-06        B
# 2  24-25/XXXXX/INIV/F(Q)401R/123458      ABC125     YYYZ   2024-12-07        C
# 3  24-25/XXXXX/INIV/F(Q)401R/123459      ABC126     ZZZA   2025-01-08        D
# 4  24-25/XXXXX/INIV/F(Q)401R/123460      ABC127     ZZZB   2025-01-09        E

# %%
df3 = pd.read_excel(xlsx, '401RR')
# df3.dropna(inplace=True)
# df3.head()

# %%
merged_xlsx1 = df1.merge(df2, left_on='IV No', right_on='Source Doc. No.', how='outer')
merged_xlsx1.drop(columns=['Source Doc. No.'], inplace=True)
# merged_xlsx1.head()

# %%
merged_xlsx2 = merged_xlsx1.merge(df3, left_on='IV No', right_on='Parent Doc. No.', how='outer')
merged_xlsx3 = merged_xlsx2.drop(columns= [
 'IV DOC TYPE',
 'StoreCode',
 'DemandNo',
 'PriorityDesc',
 'MaterialGroup',
 'SecNo',
 'InventoryNo',
 'WONo',
 'AircraftNo',
 'ClassOfItemDesc',
 'Remarks_x',
 'Job Card No',
 'Job No',
 'Job Date',
 'Task Type',
 'State',
 'Status',
 'PCD',
 'Job End Date',
 'Category',
 'Return Type',
 'RV No.',
 'Flight/Section',
 'Return Date',
 'Doc Status',
 'Store Code',
 'Remarks_y',
 'BOC Date',
 'Batch/SL No',
 ])
# merged_xlsx3.head()

# %%
merged_xlsx3.drop(columns=['Parent Doc. No.'], inplace=True)
# merged_xlsx3.head()

# %%
merged_xlsx3.rename(columns={'IV No': 'F(Q) 401 R'}, inplace=True)
# merged_xlsx3.head()

# %%
merged_xlsx3 = merged_xlsx3[['Vocab', 'Part No.', 'Item Code', 'Description', 'F(Q) 401 R', 'IssueDate', 'IssueStatusDesc', 'Workshop']]
# merged_xlsx3.head()

# %%
merged_xlsx3.loc[:, 'Qty Issued'] = pd.NA
merged_xlsx3.loc[:, 'e-MMS Asset'] = pd.NA
merged_xlsx3.loc[:, 'Work Order'] = pd.NA
merged_xlsx3.loc[:, 'Work Order Date'] = pd.NA
merged_xlsx3.loc[:, 'Work Order Status'] = pd.NA

# %%
merged_xlsx3 = merged_xlsx3[[
    'Vocab',
    'Part No.',
    'Item Code',
    'Description',
    'F(Q) 401 R',
    'IssueDate',
    'IssueStatusDesc',
    'Qty Issued',
    'Workshop',
    'e-MMS Asset',
    'Work Order',
    'Work Order Date',
    'Work Order Status'
]].copy()

# %%
merged_xlsx3.to_excel('e-MMS_State.xlsx', index=False)

# %%
# merged_xlsx3 = merged_xlsx3.drop(columns=['Batch/SL No'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-106-113eaaa3e04c> in <cell line: 1>()
# ----> 1 merged_xlsx3 = merged_xlsx3.drop(columns=['Batch/SL No'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4589                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4590             else:
# -> 4591                 new_axis = axis.drop(labels, errors=errors)
#    4592             indexer = axis.get_indexer(new_axis)
#    4593
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6697         if mask.any():
#    6698             if errors != "ignore":
# -> 6699                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700             indexer = indexer[~mask]
#    6701         return self.delete(indexer)
#
# KeyError: "['Batch/SL No'] not found in axis"

# %%
# merged_xlsx3 = pd.read_excel('merged_xlsx3.xlsx')
merged_xlsx3.head()
# Out:
#   Vocab Part No.  Item Code Description                        F(Q) 401 R  \
# 0  AAAA   AB1234   123456.0  ITEM NAME1  24-25/XXXXX/INIV/F(Q)401R/123456
# 1  AAAB   AB1235   123457.0  ITEM NAME2  24-25/XXXXX/INIV/F(Q)401R/123457
# 2  AAAC   AB1236   123458.0  ITEM NAME3  24-25/XXXXX/INIV/F(Q)401R/123458
# 3  AAAD   AB1237   123459.0  ITEM NAME4  24-25/XXXXX/INIV/F(Q)401R/123459
# 4  AAAE   AB1238   123460.0  ITEM NAME5  24-25/XXXXX/INIV/F(Q)401R/123460
#
#    IssueDate IssueStatusDesc Qty Issued Workshop e-MMS Asset Work Order  \
# 0 2024-02-05        Approved       <NA>     YYYY        <NA>       <NA>
# 1 2024-03-05          Issued       <NA>     YYYX        <NA>       <NA>
# 2 2024-04-05        Approved       <NA>     YYYZ        <NA>       <NA>
# 3 2024-05-05        Approved       <NA>     ZZZA        <NA>       <NA>
# 4 2024-06-05      Registered       <NA>     ZZZB        <NA>       <NA>
#
#   Work Order Date Work Order Status
# 0            <NA>              <NA>
# 1            <NA>              <NA>
# 2            <NA>              <NA>
# 3            <NA>              <NA>
# 4            <NA>              <NA>

# %%
merged_xlsx4 = merged_xlsx3.merge(df2, left_on='F(Q) 401 R', right_on='Source Doc. No.', how="outer")
# merged_xlsx4.head()

# %%
merged_xlsx4.drop(columns=[
  'Vocab_y',
  'Part No._y',
  'Item Code_y',
  'Description_y',
  'Source Doc. No.',
  'Workshop_y',
], inplace=True)

# merged_xlsx4.head()

# %%
merged_xlsx4['F(Q) 401 RR'] = df3['RV No.']
# merged_xlsx4.head()

# %%
merged_xlsx4['BOC Date'] = df3['BOC Date']
# merged_xlsx4.head()

# %%
merged_xlsx4['Store Code'] = df3['Store Code']
merged_xlsx4['IssueStatusDesc'] = df1['IssueStatusDesc']
merged_xlsx4['Batch/Sl No'] = df2['Batch/SL No']
merged_xlsx4['Remarks'] = df3['Remarks']
merged_xlsx4['Return Date'] = df3['Return Date']
merged_xlsx4['Doc Status'] = df3['Doc Status']

# %%
merged_xlsx4.drop(columns=['State'], inplace=True)

# %%
merged_xlsx4.rename(columns={
  'Vocab_x': 'Vocab',
  'Part No._x': 'Part No.',
  'Item Code_x': 'Item Code',
  'Description_x': 'Description',
  'Batch/SL No_x': 'Batch/SL No',
  'Workshop_x': 'Workshop',
  'PCD': 'PDC',
  'Status': 'JC Status',
}, inplace=True)

# %%
df4 = pd.read_excel(xlsx, 'TASK PROGRESS REPORT')
df4.dropna(inplace=True)
# df4.head()

# %%
merged_xlsx4['Task Qty'] = df4['Task Qty']
merged_xlsx4['Production B/C'] = df4['Production Cat B/C']
merged_xlsx4['TAF'] = df4['TAF']
merged_xlsx4['PDC Lapse'] = df4['Cat D Shortage']

# %%
merged_xlsx4 = merged_xlsx4[[
    'Vocab',
    'Part No.',
    'Item Code',
    'Description',
    'Batch/SL No',
    'F(Q) 401 R',
    'IssueDate',
    'IssueStatusDesc',
    'Qty Issued',
    'Workshop',
    'Task Qty',
    'Production B/C',
    'TAF',
    'e-MMS Asset',
    'Work Order',
    'Work Order Date',
    'Work Order Status',
    'Job Card No',
    'Job No',
    'Job Date',
    'Task Type',
    'JC Status',
    'PDC',
    'PDC Lapse',
    'Job End Date',
    'F(Q) 401 RR',
    'Return Date',
    'Doc Status',
    'Store Code',
    'Remarks',
    'BOC Date',
]]

# %%
merged_xlsx4.to_excel('production_progress_report.xlsx', index=False)
